# %%
import pandas as pd
url = "https://www.datos.gov.co/resource/sdmr-tfmf.json"
df = pd.read_json(url)
print(df)
# Out:
#        fecha_de_autorizaci_n    tipo_de_solicitud  \
# 0    2026-04-23T05:00:00.000   MÁS DE UN PACIENTE
# 1    2026-04-23T05:00:00.000   MÁS DE UN PACIENTE
# 2    2026-04-23T05:00:00.000  PACIENTE ESPECIFICO
# 3    2026-04-23T05:00:00.000  PACIENTE ESPECIFICO
# 4    2026-04-23T05:00:00.000     URGENCIA CLÍNICA
# ..                       ...                  ...
# 995  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
# 996  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
# 997  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
# 998  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
# 999  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
#
#           solicitante_importador              ium     principio_activo1  \
# 0    CREATIVE MEDICAL HEALTH SAS  1N1025871011100         NOREPINEFRINA
# 1    CREATIVE MEDICAL HEALTH SAS  1N1025871011100         NOREPINEFRINA
# 2      GLOBAL THERAPEUTICS S.A.S  1E1061661000100           ESPARSENTAN
# ...

# %%
print(df.head())
# Out:
#      fecha_de_autorizaci_n    tipo_de_solicitud       solicitante_importador  \
# 0  2026-04-23T05:00:00.000   MÁS DE UN PACIENTE  CREATIVE MEDICAL HEALTH SAS
# 1  2026-04-23T05:00:00.000   MÁS DE UN PACIENTE  CREATIVE MEDICAL HEALTH SAS
# 2  2026-04-23T05:00:00.000  PACIENTE ESPECIFICO    GLOBAL THERAPEUTICS S.A.S
# 3  2026-04-23T05:00:00.000  PACIENTE ESPECIFICO    GLOBAL THERAPEUTICS S.A.S
# 4  2026-04-23T05:00:00.000     URGENCIA CLÍNICA        UNO HEALTHCARE S.A.S.
#
#                ium principio_activo1 concentraci_n_delmedicamento1  \
# 0  1N1025871011100     NOREPINEFRINA                             1
# 1  1N1025871011100     NOREPINEFRINA                             1
# 2  1E1061661000100       ESPARSENTAN                           200
# 3  1A1014981000100         AZTREONAM                            75
# 4  1L1063461000100  LUMASIRAN SÓDICO                           189
#
#   unidad_medida1 principio_activo2 concentraci_n_del_medicamento2  \
# ...

# %%
print(df[["principio_activo1", "diagnostico_cie_1no_reporta", "cantidad_solicitada"]].head(10))
# Out:
#   principio_activo1                       diagnostico_cie_1no_reporta  \
# 0     NOREPINEFRINA                               CHOQUE CARDIOGENICO
# 1     NOREPINEFRINA                               CHOQUE CARDIOGENICO
# 2       ESPARSENTAN                                      NO REPORTADO
# 3         AZTREONAM        FIBROSIS QUISTICA, SIN OTRA ESPECIFICACION
# 4  LUMASIRAN SÓDICO                     HIPEROXALURIA PRIMARIA TIPO 1
# 5  AZTREONAM LISINA  FIBROSIS QUISTICA CON MANIFESTACIONES PULMONARES
# 6     NOREPINEFRINA                            HIPOTENSION IDIOPATICA
# 7     NOREPINEFRINA                            HIPOTENSION IDIOPATICA
# 8     NOREPINEFRINA                            HIPOTENSION IDIOPATICA
# 9     NOREPINEFRINA                            HIPOTENSION IDIOPATICA
#
#    cantidad_solicitada
# 0              15000.0
# 1              15000.0
# 2                 12.0
# 3                  3.0
# 4                  6.0
# 5                  6.0
# 6               3330.0
# ...

# %%
print(df.tail())
# Out:
#        fecha_de_autorizaci_n   tipo_de_solicitud solicitante_importador  \
# 995  2025-10-07T05:00:00.000  MÁS DE UN PACIENTE      SICMAFARMA S.A.S.
# 996  2025-10-07T05:00:00.000  MÁS DE UN PACIENTE      SICMAFARMA S.A.S.
# 997  2025-10-07T05:00:00.000  MÁS DE UN PACIENTE      SICMAFARMA S.A.S.
# 998  2025-10-07T05:00:00.000  MÁS DE UN PACIENTE      SICMAFARMA S.A.S.
# 999  2025-10-07T05:00:00.000  MÁS DE UN PACIENTE      SICMAFARMA S.A.S.
#
#                  ium     principio_activo1 concentraci_n_delmedicamento1  \
# 995  2B1025061001100           BUPIVACAINA                             5
# 996  2B1025061001100           BUPIVACAINA                             5
# 997  2B1025061001100           BUPIVACAINA                             5
# 998  2B1025061001100           BUPIVACAINA                             5
# 999  1S1015871003100  BICARBONATO DE SODIO                            84
#
#     unidad_medida1 principio_activo2 concentraci_n_del_medicamento2  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   fecha_de_autorizaci_n           1000 non-null   object
#  1   tipo_de_solicitud               1000 non-null   object
#  2   solicitante_importador          1000 non-null   object
#  3   ium                             1000 non-null   object
#  4   principio_activo1               1000 non-null   object
#  5   concentraci_n_delmedicamento1   1000 non-null   object
#  6   unidad_medida1                  999 non-null    object
#  7   principio_activo2               999 non-null    object
#  8   concentraci_n_del_medicamento2  1000 non-null   object
#  9   unidad_medida2                  999 non-null    object
#  10  forma_farmac_utica              997 non-null    object
#  11  nombre_comercial_               1000 non-null   object
# ...

# %%
df["cantidad_solicitada"] = pd.to_numeric(df["cantidad_solicitada"], errors="coerce")
print(df.describe())
# Out:
#        cantidad_solicitada
# count           999.000000
# mean           2741.299299
# std           13558.329129
# min               1.000000
# 25%               6.000000
# 50%              18.000000
# 75%             600.000000
# max          292500.000000

# %%
print(df.columns)
# Out:
# Index(['fecha_de_autorizaci_n', 'tipo_de_solicitud', 'solicitante_importador',
#        'ium', 'principio_activo1', 'concentraci_n_delmedicamento1',
#        'unidad_medida1', 'principio_activo2', 'concentraci_n_del_medicamento2',
#        'unidad_medida2', 'forma_farmac_utica', 'nombre_comercial_',
#        'cantidad_solicitada', 'presentaci_n_comercial',
#        'diagnostico_cie_1no_reporta', 'c_digo_diagnostico_cie_10'],
#       dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
print(df["principio_activo1"])
# Out:
# 0             NOREPINEFRINA
# 1             NOREPINEFRINA
# 2               ESPARSENTAN
# 3                 AZTREONAM
# 4          LUMASIRAN SÓDICO
#                ...
# 995             BUPIVACAINA
# 996             BUPIVACAINA
# 997             BUPIVACAINA
# 998             BUPIVACAINA
# 999    BICARBONATO DE SODIO
# Name: principio_activo1, Length: 1000, dtype: object

# %%
print(df[["principio_activo1","diagnostico_cie_1no_reporta","cantidad_solicitada"]])
# Out:
#         principio_activo1                 diagnostico_cie_1no_reporta  \
# 0           NOREPINEFRINA                         CHOQUE CARDIOGENICO
# 1           NOREPINEFRINA                         CHOQUE CARDIOGENICO
# 2             ESPARSENTAN                                NO REPORTADO
# 3               AZTREONAM  FIBROSIS QUISTICA, SIN OTRA ESPECIFICACION
# 4        LUMASIRAN SÓDICO               HIPEROXALURIA PRIMARIA TIPO 1
# ..                    ...                                         ...
# 995           BUPIVACAINA                                NO REPORTADO
# 996           BUPIVACAINA                                NO REPORTADO
# 997           BUPIVACAINA                                NO REPORTADO
# 998           BUPIVACAINA                                NO REPORTADO
# 999  BICARBONATO DE SODIO                                NO REPORTADO
#
#      cantidad_solicitada
# 0                15000.0
# 1                15000.0
# 2                   12.0
# ...

# %%
urgencias = df[df["tipo_de_solicitud"] == "URGENCIA CLÍNICA"]
print(urgencias)
# Out:
#        fecha_de_autorizaci_n tipo_de_solicitud  \
# 4    2026-04-23T05:00:00.000  URGENCIA CLÍNICA
# 36   2026-04-22T05:00:00.000  URGENCIA CLÍNICA
# 39   2026-04-22T05:00:00.000  URGENCIA CLÍNICA
# 69   2026-04-14T05:00:00.000  URGENCIA CLÍNICA
# 81   2026-04-14T05:00:00.000  URGENCIA CLÍNICA
# ..                       ...               ...
# 974  2025-10-10T05:00:00.000  URGENCIA CLÍNICA
# 975  2025-10-10T05:00:00.000  URGENCIA CLÍNICA
# 979  2025-10-10T05:00:00.000  URGENCIA CLÍNICA
# 986  2025-10-08T05:00:00.000  URGENCIA CLÍNICA
# 993  2025-10-08T05:00:00.000  URGENCIA CLÍNICA
#
#                      solicitante_importador                              ium  \
# 4                     UNO HEALTHCARE S.A.S.                  1L1063461000100
# 36   MULTICARE PHARMACEUTICALS COLOMBIA SAS                  1V1041501000100
# 39            VALENTECH PHARMA COLOMBIA SAS                  1E1034151000100
# 69   MULTICARE PHARMACEUTICALS COLOMBIA SAS                  1E1063881000100
# ...

# %%
df["cantidad_num"] = pd.to_numeric(df["cantidad_solicitada"], errors="coerce")
print(df[["principio_activo1","cantidad_num"]])
# Out:
#         principio_activo1  cantidad_num
# 0           NOREPINEFRINA       15000.0
# 1           NOREPINEFRINA       15000.0
# 2             ESPARSENTAN          12.0
# 3               AZTREONAM           3.0
# 4        LUMASIRAN SÓDICO           6.0
# ..                    ...           ...
# 995           BUPIVACAINA        2000.0
# 996           BUPIVACAINA        2000.0
# 997           BUPIVACAINA        2000.0
# 998           BUPIVACAINA        2000.0
# 999  BICARBONATO DE SODIO       10000.0
#
# [1000 rows x 2 columns]

# %%
df_limpio = df.drop(["unidad_medida2","principio_activo2"], axis=1)
print(df_limpio.columns)
# Out:
# Index(['fecha_de_autorizaci_n', 'tipo_de_solicitud', 'solicitante_importador',
#        'ium', 'principio_activo1', 'concentraci_n_delmedicamento1',
#        'unidad_medida1', 'concentraci_n_del_medicamento2',
#        'forma_farmac_utica', 'nombre_comercial_', 'cantidad_solicitada',
#        'presentaci_n_comercial', 'diagnostico_cie_1no_reporta',
#        'c_digo_diagnostico_cie_10', 'cantidad_num'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# fecha_de_autorizaci_n             0
# tipo_de_solicitud                 0
# solicitante_importador            0
# ium                               0
# principio_activo1                 0
# concentraci_n_delmedicamento1     0
# unidad_medida1                    1
# principio_activo2                 1
# concentraci_n_del_medicamento2    0
# unidad_medida2                    1
# forma_farmac_utica                3
# nombre_comercial_                 0
# cantidad_solicitada               1
# presentaci_n_comercial            0
# diagnostico_cie_1no_reporta       0
# c_digo_diagnostico_cie_10         0
# cantidad_num                      1
# dtype: int64

# %%
df["principio_activo2"] = df["principio_activo2"].fillna("Sin segundo principio")
print(df[["principio_activo1","principio_activo2"]].head())
# Out:
#   principio_activo1 principio_activo2
# 0     NOREPINEFRINA         NO APLICA
# 1     NOREPINEFRINA         NO APLICA
# 2       ESPARSENTAN         NO APLICA
# 3         AZTREONAM         NO APLICA
# 4  LUMASIRAN SÓDICO         NO APLICA

# %%
df.to_csv("medicamentos_invima.csv", index=False)
print("¡Archivo guardado!")
# Out:
# ¡Archivo guardado!

# %%
new_df = pd.read_csv("medicamentos_invima.csv")
print(new_df)
# Out:
#        fecha_de_autorizaci_n    tipo_de_solicitud  \
# 0    2026-04-23T05:00:00.000   MÁS DE UN PACIENTE
# 1    2026-04-23T05:00:00.000   MÁS DE UN PACIENTE
# 2    2026-04-23T05:00:00.000  PACIENTE ESPECIFICO
# 3    2026-04-23T05:00:00.000  PACIENTE ESPECIFICO
# 4    2026-04-23T05:00:00.000     URGENCIA CLÍNICA
# ..                       ...                  ...
# 995  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
# 996  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
# 997  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
# 998  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
# 999  2025-10-07T05:00:00.000   MÁS DE UN PACIENTE
#
#           solicitante_importador              ium     principio_activo1  \
# 0    CREATIVE MEDICAL HEALTH SAS  1N1025871011100         NOREPINEFRINA
# 1    CREATIVE MEDICAL HEALTH SAS  1N1025871011100         NOREPINEFRINA
# 2      GLOBAL THERAPEUTICS S.A.S  1E1061661000100           ESPARSENTAN
# ...

# %%
df = df.rename(columns={
  "principio_activo1": "medicamento",
  "diagnostico_cie_1no_reporta": "diagnostico",
  "cantidad_solicitada": "cantidad"
})
print(df.columns)
# Out:
# Index(['fecha_de_autorizaci_n', 'tipo_de_solicitud', 'solicitante_importador',
#        'ium', 'medicamento', 'concentraci_n_delmedicamento1', 'unidad_medida1',
#        'principio_activo2', 'concentraci_n_del_medicamento2', 'unidad_medida2',
#        'forma_farmac_utica', 'nombre_comercial_', 'cantidad',
#        'presentaci_n_comercial', 'diagnostico', 'c_digo_diagnostico_cie_10',
#        'cantidad_num'],
#       dtype='object')

# %%
count = df["tipo_de_solicitud"].value_counts()
print(count)
# Out:
# tipo_de_solicitud
# PACIENTE ESPECIFICO    546
# MÁS DE UN PACIENTE     359
# URGENCIA CLÍNICA        95
# Name: count, dtype: int64
